# %%
from nbindex import floating
floating.tableofcontent()
# Out:
# <script>
# // Converts integer to roman numeral
# function romanize(num) {
#     var lookup = {M:1000,CM:900,D:500,CD:400,C:100,XC:90,L:50,XL:40,X:10,IX:9,V:5,IV:4,I:1},
#         roman = '',
#         i;
#     for ( i in lookup ) {
#         while ( num >= lookup[i] ) {
#         roman += i;
#         num -= lookup[i];
#         }
#     }
#     return roman;
# }
#
# // Builds a <ul> Table of Contents from all <headers> in DOM
# function createTOC(toc_tag, maxlevel){
#     var toc = "";
#     var level = 0;
#     var levels = {};
#     $('#'+toc_tag).html('');
#
#     $(":header").each(function(i){
#         if (this.id=='tocheading'){return;}
#         if (this.tagName[1] >= maxlevel){return;}
#
#         var titleText = this.innerHTML;
#         var openLevel = this.tagName[1];
#
#         var exclude = [];
#         for (var i = 0; i < exclude.length; i++) {
#             if (titleText.indexOf(exclude[i]) !== -1){return;}
#         }
#
#         if (levels[openLevel]){
#         levels[openLevel] += 1;
#         } else{
#         levels[openLevel] = 1;
#         }
#
#         if (openLevel > level) {
#         toc += (new Array(openLevel - level + 1)).join('<ul class="'+toc_tag+'">');
#         } else if (openLevel < level) {
#         toc += (new Array(level - openLevel + 1)).join("</ul>");
#         for (i=level;i>openLevel;i--){levels[i]=0;}
#         }
#
#         level = parseInt(openLevel);
#
#         if (this.id==''){this.id = this.innerHTML.replace(/ /g,"-")}
#         var anchor = this.id;
#
#         toc += '<li><a href="#' + escape(anchor) + '">'
#         + romanize(levels[openLevel].toString()) + '. ' + titleText
#         + '</a></li>';
#
#     });
#
#     if (level) {
#     toc += (new Array(level + 1)).join("</ul>");
#     }
#
#     $('#'+toc_tag).append(toc);
# };
#
# $('<div id="toc"></div>').css({position: 'fixed', top: '160px', right: 20, background: "rgba(255, 255, 255, 0.6)"}).appendTo(document.body);
# $("#toc").css("z-index", "2000");
#
# // Executes the createToc function
# setTimeout(function(){createTOC('toc', 1 + 3);},100);
# setTimeout(function(){createTOC('toc', 1 + 3);},5000);
# setTimeout(function(){createTOC('toc', 1 + 3);},15000);
#
# // Rebuild TOC every 5 minutes
# setInterval(function(){createTOC('toc', 1 + 3);}, 300000);
#
# function toc_toggle() {
#  if ($('#toc').is(':visible')){
#      $('#toc').hide('500');
#      $('#tocButton').val('Show table of content')
#  } else {
#      $('#toc').show('500');
#      $('#tocButton').val('Hide table of content')
#  }
# }
#
# if (!($('#tocButton').length)) {
#     $('<form action="javascript:toc_toggle()" id="tocButtonForm"><input type="submit" id="tocButton" value="Hide table of content"></form>').css({position: 'fixed', top: "135px", right: "20px", background: "rgba(255, 255, 255, 0.6)"}).appendTo(document.body);
# } else {
#     document.getElementById('tocButtonForm').style.top = "135px";
#     document.getElementById('tocButtonForm').style.right = "20px";
#     $('#tocButton').val('Hide table of content')
# }
#
# </script>

# %% [markdown]
# # Plotting statistics (seaborn)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/conda/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['floating']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import pandas as pd

# %% [markdown]
# # Examination data

# %% [markdown]
# We again work on our physics examination dataset. We now focus on calculating some statistics and quick plots. Let's read the data again:

# %%
df=pd.read_csv("data/examination.csv.gz",sep=";")

# %% [markdown]
# # Basic statistics
#
# We can get a quick overview of the data by using the describe function.

# %%
df.describe()
# Out:
#           yeargroup         grade    percentage        points     questions  \
# count  19811.000000  21444.000000  21444.000000  21444.000000  20635.000000
# mean      12.737015      4.022617     66.553861    100.219269     22.418173
# std       34.817782      1.074826     19.247675     28.865995      7.112939
# min        1.000000      1.000000      0.000000      0.000000      2.000000
# 25%       12.000000      3.000000     54.000000     82.000000     18.000000
# 50%       12.000000      4.000000     70.000000    105.000000     22.000000
# 75%       12.000000      5.000000     82.000000    123.000000     28.000000
# max     2014.000000      5.000000    100.000000    150.000000     40.000000
#
#        essay_content  essay_style  complex_exercises  points_written  \
# count    5047.000000  5047.000000        5047.000000    20635.000000
# mean       12.948286     4.228849          28.152170       55.282966
# std         3.860824     1.023183          12.347646       18.886694
# min         0.000000     0.000000           0.000000        8.000000
# 25%        11.000000     4.000000          19.000000       41.000000
# 50%        14.000000     5.000000          29.000000       56.000000
# 75%        16.000000     5.000000          39.000000       70.000000
# max        18.000000     5.000000          47.000000      100.000000
#
#        measurement_content  measurement_style   points_oral          year  \
# count          5058.000000        5058.000000  20715.000000  21890.000000
# mean             35.715896           4.014433     47.302872   2013.364824
# std               9.203527           1.096126     12.863038      1.157214
# min               0.000000           0.000000      0.000000   2011.000000
# 25%              31.000000           3.000000     40.000000   2012.000000
# 50%              38.000000           4.000000     50.000000   2013.000000
# 75%              43.000000           5.000000     58.000000   2014.000000
# max              90.000000          10.000000    120.000000   2015.000000
#
#        topic_content   topic_style  complex_exercises2
# count   15657.000000  15657.000000        15588.000000
# mean       45.667369      4.162866           28.829099
# std        11.646716      1.100549           12.855951
# min         0.000000      0.000000            0.000000
# 25%        40.000000      3.000000           19.000000
# 50%        50.000000      5.000000           29.000000
# 75%        55.000000      5.000000           40.000000
# max       110.000000     10.000000           50.000000

# %%
df.describe().T
# Out:
#                        count         mean        std     min     25%     50%  \
# yeargroup            19811.0    12.737015  34.817782     1.0    12.0    12.0
# grade                21444.0     4.022617   1.074826     1.0     3.0     4.0
# percentage           21444.0    66.553861  19.247675     0.0    54.0    70.0
# points               21444.0   100.219269  28.865995     0.0    82.0   105.0
# questions            20635.0    22.418173   7.112939     2.0    18.0    22.0
# essay_content         5047.0    12.948286   3.860824     0.0    11.0    14.0
# essay_style           5047.0     4.228849   1.023183     0.0     4.0     5.0
# complex_exercises     5047.0    28.152170  12.347646     0.0    19.0    29.0
# points_written       20635.0    55.282966  18.886694     8.0    41.0    56.0
# measurement_content   5058.0    35.715896   9.203527     0.0    31.0    38.0
# measurement_style     5058.0     4.014433   1.096126     0.0     3.0     4.0
# points_oral          20715.0    47.302872  12.863038     0.0    40.0    50.0
# year                 21890.0  2013.364824   1.157214  2011.0  2012.0  2013.0
# topic_content        15657.0    45.667369  11.646716     0.0    40.0    50.0
# topic_style          15657.0     4.162866   1.100549     0.0     3.0     5.0
# complex_exercises2   15588.0    28.829099  12.855951     0.0    19.0    29.0
#
#                         75%     max
# yeargroup              12.0  2014.0
# grade                   5.0     5.0
# percentage             82.0   100.0
# points                123.0   150.0
# questions              28.0    40.0
# essay_content          16.0    18.0
# essay_style             5.0     5.0
# complex_exercises      39.0    47.0
# points_written         70.0   100.0
# measurement_content    43.0    90.0
# measurement_style       5.0    10.0
# points_oral            58.0   120.0
# year                 2014.0  2015.0
# topic_content          55.0   110.0
# topic_style             5.0    10.0
# complex_exercises2     40.0    50.0

# %% [markdown]
# The `corr` function gives us the Pearson/Speaman/Kendall correlation table.

# %%
df.corr(method="pearson")
# Out:
#                      yeargroup     grade  percentage    points  questions  \
# yeargroup             1.000000  0.013730   -0.000021  0.000101  -0.006200
# grade                 0.013730  1.000000    0.907772  0.906896   0.507316
# percentage           -0.000021  0.907772    1.000000  0.998582   0.684114
# points                0.000101  0.906896    0.998582  1.000000   0.684060
# questions            -0.006200  0.507316    0.684114  0.684060   1.000000
# essay_content        -0.012108  0.560202    0.663993  0.664042   0.356895
# essay_style          -0.016003  0.445160    0.500275  0.500438   0.256725
# complex_exercises    -0.008011  0.707938    0.891349  0.891243   0.534321
# points_written        0.006674  0.846829    0.903683  0.904050   0.652535
# measurement_content  -0.008256  0.775403    0.805784  0.796333   0.415918
# measurement_style     0.014697  0.645829    0.686136  0.676032   0.335439
# points_oral          -0.012063  0.632853    0.759383  0.748877   0.474384
# year                  0.012776  0.049254    0.019835  0.019255  -0.107093
# topic_content         0.006201  0.787951    0.810324  0.799206   0.400883
# topic_style          -0.000067  0.666969    0.687220  0.676825   0.350101
# complex_exercises2    0.050594  0.842976    0.895515  0.895725   0.639866
#
#                      essay_content  essay_style  complex_exercises  \
# yeargroup                -0.012108    -0.016003          -0.008011
# grade                     0.560202     0.445160           0.707938
# percentage                0.663993     0.500275           0.891349
# points                    0.664042     0.500438           0.891243
# questions                 0.356895     0.256725           0.534321
# essay_content             1.000000     0.646490           0.518907
# essay_style               0.646490     1.000000           0.370415
# complex_exercises         0.518907     0.370415           1.000000
# points_written            0.686980     0.506517           0.941172
# measurement_content       0.433555     0.344682           0.550949
# measurement_style         0.392058     0.332567           0.459826
# points_oral               0.436247     0.349502           0.550095
# year                      0.131977     0.076108           0.081351
# topic_content                  NaN          NaN                NaN
# topic_style                    NaN          NaN                NaN
# complex_exercises2             NaN          NaN                NaN
#
#                      points_written  measurement_content  measurement_style  \
# yeargroup                  0.006674            -0.008256           0.014697
# grade                      0.846829             0.775403           0.645829
# percentage                 0.903683             0.805784           0.686136
# points                     0.904050             0.796333           0.676032
# questions                  0.652535             0.415918           0.335439
# essay_content              0.686980             0.433555           0.392058
# essay_style                0.506517             0.344682           0.332567
# complex_exercises          0.941172             0.550949           0.459826
# points_written             1.000000             0.591616           0.499105
# measurement_content        0.591616             1.000000           0.832555
# measurement_style          0.499105             0.832555           1.000000
# points_oral                0.420815             0.994463           0.861251
# year                       0.025150             0.009425           0.007014
# topic_content              0.544409                  NaN                NaN
# topic_style                0.468870                  NaN                NaN
# complex_exercises2         0.954703                  NaN                NaN
#
#                      points_oral      year  topic_content  topic_style  \
# yeargroup              -0.012063  0.012776       0.006201    -0.000067
# grade                   0.632853  0.049254       0.787951     0.666969
# percentage              0.759383  0.019835       0.810324     0.687220
# points                  0.748877  0.019255       0.799206     0.676825
# questions               0.474384 -0.107093       0.400883     0.350101
# essay_content           0.436247  0.131977            NaN          NaN
# essay_style             0.349502  0.076108            NaN          NaN
# complex_exercises       0.550095  0.081351            NaN          NaN
# points_written          0.420815  0.025150       0.544409     0.468870
# measurement_content     0.994463  0.009425            NaN          NaN
# measurement_style       0.861251  0.007014            NaN          NaN
# points_oral             1.000000 -0.022371       0.995005     0.836474
# year                   -0.022371  1.000000       0.002093     0.011521
# topic_content           0.995005  0.002093       1.000000     0.809229
# topic_style             0.836474  0.011521       0.809229     1.000000
# complex_exercises2      0.552048  0.030493       0.550518     0.471478
#
#                      complex_exercises2
# yeargroup                      0.050594
# grade                          0.842976
# percentage                     0.895515
# points                         0.895725
# questions                      0.639866
# essay_content                       NaN
# essay_style                         NaN
# complex_exercises                   NaN
# points_written                 0.954703
# measurement_content                 NaN
# measurement_style                   NaN
# points_oral                    0.552048
# year                           0.030493
# topic_content                  0.550518
# topic_style                    0.471478
# complex_exercises2             1.000000

# %% [markdown]
# We can easily plot it e.g. the [Pearson correlation]()

# %%
c=df.corr(method="pearson")
figsize(10,8)
imshow(c,interpolation="none",cmap='BrBG')
xticks(range(len(c.index)),c.index,rotation=90)
yticks(range(len(c.index)),c.index)
colorbar();

# %% [markdown]
# ## Plotting

# %% [markdown]
# A very great strength of `pandas` is that we can make plots from `DataFrame`s with a very quick syntax. `pandas` uses the `matplotlib` library for these purposes, therefore, we have to import it.

# %% [markdown]
# We can set the parameters of the plot (title, ylabel etc.) similarly to the methods we've already seen in `matplotlib`.
#
# First, we increase the font size of the axis labels:

# %%
rcParams["font.size"]=12

# %% [markdown]
# Distributions

# %%
points=df[['points_written',
         'complex_exercises']]
points.head()
# Out:
#    points_written  complex_exercises
# 0             NaN                NaN
# 1             NaN                NaN
# 2            86.0                NaN
# 3            23.0                NaN
# 4            66.0                NaN

# %%
points.hist(figsize=(8,4));

# %%
points.plot.hist(figsize=(9,6),alpha=0.5);

# %%
points.plot.box(figsize=(9,6));

# %% [markdown]
# Covariances

# %%
points.plot.scatter(x='points_written',y= 'complex_exercises');

# %%
points.plot.hexbin(x='points_written',y= 'complex_exercises',gridsize=20);

# %% [markdown]
# Histograms and covariances together.

# %%
pd.plotting.scatter_matrix(points,figsize=(9,9));

# %% [markdown]
# ### Further figures

# %% [markdown]
# The number of normal and advanced level students in time:

# %%
toplot=df.groupby(['level_abbrev','year'])[['level']].count()
toplot
# Out:
#                    level
# level_abbrev year
# A            2011     50
#              2012   1152
#              2013   1457
#              2014   1462
#              2015   1357
# N            2011    358
#              2012   4829
#              2013   4176
#              2014   3491
#              2015   3558

# %% [markdown]
# Let's use the `unstack` function to plot the groups easily:

# %%
toplot=toplot.unstack(level=0)
toplot
# Out:
#              level
# level_abbrev     A     N
# year
# 2011            50   358
# 2012          1152  4829
# 2013          1457  4176
# 2014          1462  3491
# 2015          1357  3558

# %%
toplot.plot(kind="area", figsize=(9, 6))
ylabel("Number of students")
ylim(0,7000)
xticks(range(2011,2016),map(str,range(2011,2016)));

# %% [markdown]
# We could have a look at some pie charts to count which school type sent the students to normal or advanced level exams between 2011 and 2015. We make two subplots for that. What did the `autopct` keyword do? What can `-` be?

# %%
t=df[(df["attendance"]=="present")].groupby(["level_abbrev","school_type"])
t=t.size().unstack(level=1)
t.head()
# Out:
# school_type     -  comprehensive  vocational
# level_abbrev
# A             510           4135         413
# N             750          10313        4594

# %%
t.rename({"-":"Other"}, axis=1, inplace=True)
t.head()
# Out:
# school_type   Other  comprehensive  vocational
# level_abbrev
# A               510           4135         413
# N               750          10313        4594

# %%
t.plot.pie(subplots=True,autopct="%.1f",figsize=(12,4));

# %% [markdown]
# ## Seaborn package

# %%
import seaborn as sns
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# This is a package that makes it easy to create nicely looking statistics plots.

# %% [markdown]
# Histogram and density function estimation:

# %%
sns.distplot(df['points_written'].dropna());

# %% [markdown]
# Only kernel density estimate:

# %%
sns.kdeplot(df['points_written']);

# %% [markdown]
# Estimated cumulative distribution function.

# %%
sns.kdeplot(df['points_written'].dropna(),cumulative=True);

# %% [markdown]
# More distributions in one plot:

# %%
points=df.loc[df['level_abbrev']=='N',['points_written',
           'points_oral',
           'school_type']]
points.head()
# Out:
#    points_written  points_oral    school_type
# 0             NaN          NaN  comprehensive
# 1             NaN          NaN  comprehensive
# 2            86.0         60.0  comprehensive
# 3            23.0         38.0  comprehensive
# 4            66.0         60.0  comprehensive

# %% [markdown]
# Drawing all the points:

# %%
sns.stripplot(x='school_type', y='points_written',
              data=points.dropna().iloc[:1000],jitter=True);

# %% [markdown]
# Boxplots:

# %%
sns.boxplot(x='school_type', y='points_written',
              data=points);

# %% [markdown]
# Density functions next to each other:

# %%
sns.violinplot(x='school_type', y='points_written',
              data=points);

# %% [markdown]
# Multidimensional distributions:

# %%
x='points_written'
y='points_oral'

# %% [markdown]
# Estimated density:

# %%
sns.jointplot(x=x, y=y, data=points, kind="kde");

# %% [markdown]
# Histograms:

# %%
sns.jointplot(x=x, y=y, data=points,kind="hex", color="k");

# %% [markdown]
# Pairplot from the previous notebooks.

# %%
sns.pairplot(points.dropna());

# %% [markdown]
# Linear models:

# %%
sns.lmplot(x=y, y=x, data=points.dropna().iloc[:30,:]);

# %% [markdown]
# With histograms:

# %%
sns.jointplot(x=y, y=x, data=points.dropna().iloc[:30,:],kind='reg');
