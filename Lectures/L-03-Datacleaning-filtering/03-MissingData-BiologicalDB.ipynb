# %%
#!pip install missingno --user

# %%
import missingno as msno
import pandas as pd
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# These are cleaned data !!!
data = pd.read_feather("/home/wfct0p/Noronet-data/noronet_all_clean.fr")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82900 entries, 0 to 82899
# Data columns (total 53 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   User                                       82900 non-null  object
#  1   Institute                                  82900 non-null  object
#  2   Database ID                                82900 non-null  int64
#  3   Country                                    82900 non-null  category
#  4   Submission Date                            82900 non-null  datetime64[ns]
#  5   Last Update                                28776 non-null  datetime64[ns]
#  6   Outbreak Nr                                82900 non-null  object
#  7   Sample Date                                82900 non-null  datetime64[ns]
#  8   Outbreak or sporadic case O/S              56752 non-null  object
#  9   Source of the sample                       79640 non-null  object
#  10  Specify source                             516 non-null    object
#  11  Specify animal                             92 non-null     object
#  12  Suspected country of infection             75908 non-null  object
#  13  Date of first disease                      42320 non-null  datetime64[ns]
#  14  Geo-coded location                         78260 non-null  object
#  15  Suspected mode of transmission             36608 non-null  object
#  16  Specify other mode of transmission         524 non-null    object
#  17  Food item                                  2780 non-null   object
#  18  Specify food item                          1576 non-null   object
#  19  Setting of the outbreak                    44772 non-null  category
#  20  Specify setting                            12212 non-null  object
#  21  Point source transmission Y/N              31332 non-null  object
#  22  Date of point source transmission          1104 non-null   datetime64[ns]
#  23  Nr of persons affected                     21236 non-null  object
#  24  Nr of persons at risk                      11620 non-null  object
#  25  Nr of cases deceased                       9044 non-null   object
#  26  Nr of cases hospitalized due to infection  10628 non-null  object
#  27  Nr of cases of ages 0 to 4                 3464 non-null   object
#  28  Nr of cases of ages 5 to 14                3380 non-null   object
#  29  Nr of cases of ages 15 to 64               6324 non-null   object
#  30  Nr of cases of age 65 or older             6588 non-null   object
#  31  Nr of cases with vomiting                  5584 non-null   object
#  32  Nr of cases with diarrhea                  5856 non-null   object
#  33  Mixed infection Y/N                        39852 non-null  object
#  34  Specify other pathogen(s)                  920 non-null    object
#  35  Nr of samples tested                       20976 non-null  object
#  36  Nr of PCR positive samples                 28528 non-null  object
#  37  Nr of PCR negative samples                 24464 non-null  object
#  38  Included in II.4 P2 capsid surveillance    12032 non-null  object
#  39  fasta_id                                   26523 non-null  object
#  40  reference_id                               25977 non-null  object
#  41  fragment_begin                             25977 non-null  float64
#  42  Genus-Genogroup                            82900 non-null  category
#  43  ORF1                                       17168 non-null  object
#  44  ORF1_variant                               7704 non-null   object
#  45  ORF2                                       10455 non-null  object
#  46  ORF2_variant                               6221 non-null   object
#  47  Reference_sequence_for_positions           25977 non-null  object
#  48  Cluster                                    18079 non-null  object
#  49  ORF1_genotype                              82900 non-null  category
#  50  ORF1_genogroup                             82900 non-null  category
#  51  ORF2_genotype                              82900 non-null  category
#  52  ORF2_genogroup                             82900 non-null  category
# dtypes: category(7), datetime64[ns](5), float64(1), int64(1), object(39)
# memory usage: 29.7+ MB

# %% [markdown]
# ### We drop those columns that are complete

# %%
# we don't need those, which are complete columns
drop_cols = ['User', 'Institute', 'Database ID', 'Country', 'Submission Date',
       'Outbreak Nr', 'Sample Date',
       'fasta_id', 'Genus-Genogroup', 'ORF1',
       'ORF2']
data.drop(drop_cols, axis=1, inplace=True)

# %%
#msno.matrix(data.sample(250))
msno.matrix(data)

# %%
msno.bar(data)

# %% [markdown]
# ## Nullity correlation
# * -1,  if one variable appears the other definitely does not
# * 0, variables appearing or not appearing have no effect on one another
# * 1, if one variable appears the other definitely also does
#
# Variables that are always full or always empty have no meaningful correlation, and so are silently removed from the visualization—in this case for instance the datetime and injury number columns, which are completely filled, are not included.

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt

# from matplotlib.pyplot import grid

# fig, ax = plt.subplots(figsize=(20,12))
msno.heatmap(data)#.sample(100), ax=ax)
# ax.grid(color='r', linestyle='-', linewidth=2)
# ax.grid(True)#, markevery=0)
# ax.figure.figsize=(28,16)

# %% [markdown]
# ### Dendrogram
# The dendrogram uses a hierarchical clustering algorithm (courtesy of scipy) to bin variables against one another by their nullity correlation (measured in terms of binary distance). At each step of the tree the variables are split up based on which combination minimizes the distance of the remaining clusters. The more monotone the set of variables, the closer their total distance is to zero, and the closer their average distance (the y-axis) is to zero.

# %%
msno.dendrogram(data)

# %% [markdown]
# Citation
#
# You may cite this package using the following format (via this paper):
#
#     Bilogur, (2018). Missingno: a missing data visualization suite. Journal of Open Source Software, 3(22), 547, https://doi.org/10.21105/joss.00547
