# %%
# !pip install --user xmltodict

# %%
import random
import pytz
import shapely
from shapely.geometry import Point
import elasticsearch
from datetime import datetime
import time

# %%
# define mapping
mapping = {
        "mappings": {
            #"mydocs": {
                "properties": {
                    "Date": {
                     "type": "date"
                    },
                    "Destination": {
                     "type": "geo_point"
                    },
                    "Origin": {
                      "type": "geo_point"
                    },
                    "Title": {
                      "type": "keyword"
                    },
                }
            #}
       }
}

# %%
# load Elasticsearch
try:
    es = elasticsearch.Elasticsearch(["kooplex-fiek.elte.hu"],port=9100)
except:
    print( "unable to es")

# %%
# create index mass_traffic
try:
    response = es.indices.create(index="random_point",body=mapping, ignore=400)
except Exception as e:
    print(e)

# %%
response
# Out:
# {'error': {'root_cause': [{'type': 'resource_already_exists_exception',
#     'reason': 'index [random_point/qtb5UihITvKYhDahdYH0VA] already exists',
#     'index_uuid': 'qtb5UihITvKYhDahdYH0VA',
#     'index': 'random_point'}],
#   'type': 'resource_already_exists_exception',
#   'reason': 'index [random_point/qtb5UihITvKYhDahdYH0VA] already exists',
#   'index_uuid': 'qtb5UihITvKYhDahdYH0VA',
#   'index': 'random_point'},
#  'status': 400}

# %%
now = pytz.utc.localize(datetime.utcnow())
id=1
latr1, latr2, lonr1, lonr2 = [random.uniform(-10,10) for i in range(4)]
while True:
    try:
        new_body = {}
        new_body["Date"] =  datetime.strftime(now,'%Y-%m-%dT%H:%M:%S.%fZ')
        p = Point((random.uniform(0.2+latr1,23+latr1), random.uniform(45.5+lonr1,49+lonr1))) 
        new_body["Destination"] = { "lat": p.x, 'lon': p.y}                
        p = Point((random.uniform(-43+latr2,-10+latr2), random.uniform(25.5+lonr2,39+lonr2))) 
        new_body["Origin"] = {"lat": p.x, 'lon': p.y}              

        new_body["Title"] = random.choice(['flight1, flight2, flight3'])
        id+=1


        print(new_body)
        res = es.index(index="random_point", doc_type="_doc", id=id, body=new_body)
        print( "------------------------------------------")
        print(res)
    except Exception as e:
        print( "------------------------------------------")
        print("unable to index in elasticsearch")
        print( "------------------------------------------")
        error = "{0}: {1}".format(id,e)
        print( error)
        print( "------------------------------------------")
    print( "all done, starting again soon")
    time.sleep(5)
    if id==30:
        id=1
        latr1, latr2, lonr1, lonr2 = random(4)
        latr1, latr2, lonr1, lonr2 = [random.uniform(-10,10) for i in range(4)]
# Out:
# {'Date': '2020-11-18T22:22:46.992122Z', 'Destination': {'lat': 2.446666040740263, 'lon': 39.691025283524425}, 'Origin': {'lat': -40.997995434117186, 'lon': 33.4908122609994}, 'Title': 'flight1, flight2, flight3'}
# ------------------------------------------
# {'_index': 'random_point', '_type': '_doc', '_id': '2', '_version': 4, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 245, '_primary_term': 1}
# all done, starting again soon
# {'Date': '2020-11-18T22:22:46.992122Z', 'Destination': {'lat': 15.635578954524437, 'lon': 40.177133412237296}, 'Origin': {'lat': -15.880408809584328, 'lon': 26.700175268293563}, 'Title': 'flight1, flight2, flight3'}
# ------------------------------------------
# {'_index': 'random_point', '_type': '_doc', '_id': '3', '_version': 3, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 246, '_primary_term': 1}
# all done, starting again soon
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-4b1b012e76e4> in <module>
#      27         print( "------------------------------------------")
#      28     print( "all done, starting again soon")
# ---> 29     time.sleep(5)
#      30     if id==30:
#      31         id=1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Queries DSL
#
# GET random_point/_search
# {
#    "query": {
#     "bool": {
#       "must": {
#         "match_all": {}
#       },
#       "filter": {
#         "geo_bounding_box": {
#           "Origin": {
#             "top_left": {
#               "lat": -28.6603547,
#               "lon": 0.2268691
#             },
#             "bottom_right": {
#               "lat": -48.3658642,
#               "lon": -26.9556643
#             }
#           }
#         }
#       }
#     }
#   }
# }

# %%
res=es.get(index='mass_traffic',doc_type='record',id='massdot1-daeaf7570000')
res

# %%
res= es.search(index='mass_traffic',body={'query':{'match_all':{}}})

# %%
res['hits']['total']
# Out:
# {'value': 222, 'relation': 'eq'}

# %%
res= es.search(index='mass_traffic',body={'query':{'match':{'Status':'Active'}}})

# %%
res
# Out:
# {'took': 148,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'failed': 0},
#  'hits': {'total': 32,
#   'max_score': 0.087011375,
#   'hits': [{'_index': 'mass_traffic',
#     '_type': 'record',
#     '_id': 'massdot1-0e0d21570000',
#     '_score': 0.087011375,
#     '_source': {'LastUpdated': '2020-11-18T19:33:40',
#      'PairID': 'massdot1-0e0d21570000',
#      'Destination': 'Yankee Division Hwy after Exit 20B in Beverly',
#      'FreeFlow': 55.0,
#      'Origin': 'Yankee Division Hwy before Exit 21 in Beverly',
#      'Speed': 109.0,
#      'Status': 'Active',
#      'Title': 'Yankee Division Hwy before Exit 21 in Beverly to Yankee Division Hwy after Exit 20B in Beverly',
#      'TravelTime': 27.0,
#      'dnid': '3086',
#      'onid': '3063',
#      'Route': {'type': 'LineString',
#       'coordinates': [[-70.8937460184082, 42.5743799003251],
#        [-70.8947438001617, 42.5742297866267],
#        [-70.8960580825794, 42.5740559703139],
#        [-70.8982092142091, 42.5737320386199],
#        [-70.9004193544375, 42.5734002044086],
#        [-70.9024524688705, 42.5731078728075],
#        [-70.9030506014811, 42.5730170127062],
#        [-70.9035682678213, 42.5729301029202]]}}},
#    {'_index': 'mass_traffic',
#     '_type': 'record',
#     '_id': 'massdot1-060b21570000',
#     '_score': 0.087011375,
#     '_source': {'LastUpdated': '2020-11-18T19:33:40',
#      'PairID': 'massdot1-060b21570000',
#      'Destination': 'Yankee Division Hwy before Exit 21 in Beverly',
#      'FreeFlow': 55.0,
#      'Origin': 'Yankee Division Hwy before Exit 24 in Peabody',
#      'Speed': 93.0,
#      'Status': 'Active',
#      'Title': 'Yankee Division Hwy before Exit 24 in Peabody to Yankee Division Hwy before Exit 21 in Beverly',
#      'TravelTime': 160.0,
#      'dnid': '3063',
#      'onid': '3052',
#      'Route': {'type': 'LineString',
#       'coordinates': [[-70.9035682678224, 42.5729459047095],
#        [-70.9043461084366, 42.5727997380151],
#        [-70.9051024913786, 42.5726377691159],
#        [-70.9057703614233, 42.5724580226504],
#        [-70.9064060449597, 42.5722782756668],
#        [-70.9068673849103, 42.5721084044149],
#        [-70.9072053432462, 42.5719721120294],
#        [-70.9075111150739, 42.5718318688291],
#        [-70.9078195691102, 42.5716679221526],
#        [-70.9083305299274, 42.5713864464321],
#        [-70.9088595956556, 42.5711192902312],
#        [-70.9093672037116, 42.5709034903943],
#        [-70.9098446369163, 42.5707380598079],
#        [-70.9105527400964, 42.5705133698013],
#        [-70.9117329120631, 42.5701983086046],
#        [-70.9130257368085, 42.5698318874683],
#        [-70.9144365787505, 42.5694378095041],
#        [-70.9160807728766, 42.5689854562902],
#        [-70.9174889326093, 42.568572607044],
#        [-70.9186476469039, 42.568177533437],
#        [-70.9195220470429, 42.5677824573276],
#        [-70.9201925992967, 42.5674426898723],
#        [-70.9208524227142, 42.5670436582884],
#        [-70.9214317798613, 42.5666288207672],
#        [-70.9221720695494, 42.5659927312103],
#        [-70.9226521849631, 42.5654810892513],
#        [-70.9232127666472, 42.5647837480867],
#        [-70.9239745140072, 42.5636458602145],
#        [-70.924886465072, 42.5622827380456],
#        [-70.9257447719572, 42.5610183662227],
#        [-70.9259754419324, 42.5607121473176],
#        [-70.9263134002683, 42.5603259142328],
#        [-70.9267586469649, 42.5598601593918],
#        [-70.9271502494811, 42.5595107175016],
#        [-70.9280085563659, 42.5587582377551],
#        [-70.9300202131266, 42.5570433304146],
#        [-70.9322410821913, 42.5551387006666],
#        [-70.9338665008544, 42.5537398276859],
#        [-70.9347677230834, 42.5529791279463],
#        [-70.9350413084028, 42.5527005316961],
#        [-70.935298800468, 42.552421934202],
#        [-70.9357520937914, 42.5517906395342],
#        [-70.9360243380064, 42.5512378809787],
#        [-70.9361550956958, 42.5509140777816],
#        [-70.9362912178033, 42.5503966313518],
#        [-70.9363716840738, 42.549695169677],
#        [-70.9364360570901, 42.5488079575637],
#        [-70.9364816546434, 42.5481815663613],
#        [-70.9364897012705, 42.5476737303941]]}}},
#    {'_index': 'mass_traffic',
#     '_type': 'record',
#     '_id': 'massdot1-0af6e1570000',
#     '_score': 0.087011375,
#     '_source': {'LastUpdated': '2020-11-18T19:33:40',
#      'PairID': 'massdot1-0af6e1570000',
#      'Destination': '3008 - R-58 - 93NB-TTR-34.5',
#      'FreeFlow': 65.0,
#      'Origin': '3124 - G-36 - 93SB-TTS-36.1',
#      'Speed': 115.0,
#      'Status': 'Active',
#      'Title': '3124 - G-36 - 93SB-TTS-36.1 to 3008 - R-58 - 93NB-TTR-34.5',
#      'TravelTime': 82.0,
#      'dnid': '3008',
#      'onid': '3124',
#      'Route': {'type': 'LineString',
#       'coordinates': [[-71.1713761091237, 42.6022292058815],
#        [-71.1709845066075, 42.6009459005224],
#        [-71.1706519126898, 42.5997770824878],
#        [-71.1702173948294, 42.5983298500474],
#        [-71.1699411273009, 42.5976022723379],
#        [-71.1695468425757, 42.5966930350633],
#        [-71.169037222863, 42.5957650267706],
#        [-71.1685276031502, 42.594900189581],
#        [-71.1681313067682, 42.5943557111528],
#        [-71.1677242815502, 42.5938191262164],
#        [-71.1670818924911, 42.5930618770568],
#        [-71.1665736138827, 42.5925238000285],
#        [-71.1661297082908, 42.5920647031114],
#        [-71.1654256284242, 42.5913913548492],
#        [-71.1647430062298, 42.5907179993125],
#        [-71.163404583931, 42.5894147098663],
#        [-71.1619937419894, 42.5880047569609],
#        [-71.1613070964819, 42.5873372891412],
#        [-71.1603656411178, 42.5864269147055],
#        [-71.1594456434257, 42.5855244262746],
#        [-71.1583325266842, 42.5844283888395],
#        [-71.1572140455247, 42.5833125831886],
#        [-71.155926585198, 42.5819380411649]]}}},
#    {'_index': 'mass_traffic',
#     '_type': 'record',
#     '_id': 'AXXc7Gc0BFAfUdiIDHV3',
#     '_score': 0.087011375,
#     '_source': {'LastUpdated': '2020-11-18T19:52:12',
#      'PairID': 'massdot1-5b08da570000',
#      'Destination': '3267 - G-82 - 3SB-TTS-37.8',
#      'FreeFlow': 60.0,
#      'Origin': '3283 - G-124 - 3NB-TTS-36.8',
#      'Speed': 98.0,
#      'Status': 'Active',
#      'Title': '3283 - G-124 - 3NB-TTS-36.8 to 3267 - G-82 - 3SB-TTS-37.8',
#      'TravelTime': 55.0,
#      'dnid': '3267',
#      'onid': '3283',
#      'Route': {'type': 'LineString',
#       'coordinates': [[-70.9288561344157, 42.1861687262349],
#        [-70.9299182891851, 42.1866417322432],
#        [-70.9309267997746, 42.1871028103248],
#        [-70.9317582845694, 42.1874843896419],
#        [-70.9324502944955, 42.1877467240863],
#        [-70.9329223632817, 42.1879096888748],
#        [-70.9336304664613, 42.1881004763861],
#        [-70.934461951256, 42.1882932506825],
#        [-70.9352880716326, 42.1884621761291],
#        [-70.9360176324846, 42.1886291137737],
#        [-70.9367686510087, 42.1887960509775],
#        [-70.9376403689387, 42.1889788864573],
#        [-70.9385013580328, 42.1891696707419],
#        [-70.9392738342291, 42.1893525051405],
#        [-70.9397459030158, 42.1894637953851],
#        [-70.9401965141303, 42.1895989332759],
#        [-70.9407007694251, 42.189738045509],
#        [-70.9415912628182, 42.1900122944432],
#        [-70.9429055452353, 42.1904455258417],
#        [-70.9436538815504, 42.1906899624306],
#        [-70.9442305564886, 42.1909026016213],
#        [-70.9447079896933, 42.1911251764566],
#        [-70.9451049566275, 42.191300056135],
#        [-70.9454751014713, 42.1914709608071]]}}},
#    {'_index': 'mass_traffic',
#     '_type': 'record',
#     '_id': 'massdot1-aa3626580000',
#     '_score': 0.087011375,
#     '_source': {'LastUpdated': '2020-11-18T20:02:04',
#      'PairID': 'massdot1-aa3626580000',
#      'Destination': 'Rt. 3 SB before Exit 2 to Herring Pond Rd in Cedarville(Location 3)',
#      'FreeFlow': 60.0,
#      'Origin': '3247 - G-87 - 3SB-TTS-6.8',
#      'Speed': 115.0,
#      'Status': 'Active',
#      'Title': '3247 - G-87 - 3SB-TTS-6.8 to Rt. 3 SB before Exit 2 to Herring Pond Rd in Cedarville(Location 3)',
#      'TravelTime': 189.0,
#      'dnid': '2042',
#      'onid': '3247',
#      'Route': {'type': 'LineString',
#       'coordinates': [[-70.5951301266038, 41.867500081636],
#        [-70.591353576311, 41.864080415908],
#        [-70.5858389545766, 41.8589026299788],
#        [-70.5826632191027, 41.8561217941251],
#        [-70.5806676555958, 41.8541719405512],
#        [-70.5793587375961, 41.852829383864],
#        [-70.5780498195973, 41.8510872147248],
#        [-70.5738870312063, 41.8454288335318],
#        [-70.5709258724533, 41.841368556728],
#        [-70.5677501369803, 41.8371481534383],
#        [-70.5647460628836, 41.8329914236119],
#        [-70.5614630390488, 41.8285466215406],
#        [-70.5600682903609, 41.8264200423379],
#        [-70.5583087612476, 41.8227583231515],
#        [-70.5576864887559, 41.8213298226853]]}}},
#    {'_index': 'mass_traffic',
#     '_type': 'record',
#     '_id': 'massdot1-580cf8570000',
#     '_score': 0.074107975,
#     '_source': {'LastUpdated': '2020-11-18T19:33:40',
#      'PairID': 'massdot1-580cf8570000',
#      'Destination': '3356 - R-120 - 90EB-TTR-122.7',
#      'FreeFlow': 57.0,
#      'Origin': '3346 - R-101 - 90EB-TTR-123.3',
#      'Speed': 79.0,
#      'Status': 'Active',
#      'Title': '3346 - R-101 - 90EB-TTR-123.3 to 3356 - R-120 - 90EB-TTR-122.7',
#      'TravelTime': 39.0,
#      'dnid': '3356',
#      'onid': '3346',
#      'Route': {'type': 'LineString',
#       'coordinates': [[-71.2651729583753, 42.3391427243329],
#        [-71.2668251991286, 42.3388730885916],
#        [-71.2738847732554, 42.339095141639],
#        [-71.2755370140087, 42.3389999761431]]}}},
#    {'_index': 'mass_traffic',
#     '_type': 'record',
#     '_id': 'massdot1-e8fbf7570000',
#     '_score': 0.074107975,
#     '_source': {'LastUpdated': '2020-11-18T19:33:40',
#      'PairID': 'massdot1-e8fbf7570000',
#      'Destination': '3038 - R-23 - 90WB-TTR-90.3',
#      'FreeFlow': 65.0,
#      'Origin': '3291 - G-20 - 90EB-TTS-88.6',
#      'Speed': 100.0,
#      'Status': 'Active',
#      'Title': '3291 - G-20 - 90EB-TTS-88.6 to 3038 - R-23 - 90WB-TTR-90.3',
#      'TravelTime': 98.0,
#      'dnid': '3038',
#      'onid': '3291',
#      'Route': {'type': 'LineString',
#       'coordinates': [[-71.8789106607457, 42.186077739248],
#        [-71.8775427341487, 42.1864434254019],
#        [-71.8761640787145, 42.186817059071],
#        [-71.875573992731, 42.1869959254708],
#        [-71.8747586011911, 42.1872542871559],
#        [-71.8740934133549, 42.1875126477845],
#        [-71.8732833862323, 42.1878306286468],
#        [-71.8728220462824, 42.1880492395621],
#        [-71.8715292215372, 42.188605700299],
#        [-71.8700593709966, 42.1892376747666],
#        [-71.8690347671535, 42.1896868100124],
#        [-71.8681764602687, 42.1900008053248],
#        [-71.8671357631709, 42.1903306974535],
#        [-71.8660038709665, 42.1906208421195],
#        [-71.8646788597132, 42.1909030363389],
#        [-71.8632304668451, 42.1911256111725],
#        [-71.8623399734518, 42.1912170256095],
#        [-71.8612349033375, 42.1913203635095],
#        [-71.8596577644366, 42.1914276757649],
#        [-71.8572491407419, 42.1916184526581],
#        [-71.8562996387504, 42.1917297389132],
#        [-71.8553313612959, 42.1918728209535],
#        [-71.8544811010379, 42.1920318006183],
#        [-71.8535637855554, 42.192250397005],
#        [-71.8526947498345, 42.1924968138432],
#        [-71.8513751029992, 42.1929340026431],
#        [-71.8507206439996, 42.1931843912301],
#        [-71.8492347002053, 42.1937726017862],
#        [-71.8481993675256, 42.1942217048091],
#        [-71.8481886386892, 42.1942217048091]]}}},
#    {'_index': 'mass_traffic',
#     '_type': 'record',
#     '_id': 'massdot1-cea211550000',
#     '_score': 0.074107975,
#     '_source': {'LastUpdated': '2020-11-18T19:33:40',
#      'PairID': 'massdot1-cea211550000',
#      'Destination': 'Rt. 6 WB before Exit 2 to Rt. 130 in Sandwich (Location 6)',
#      'Origin': 'Rt. 6 EB before Exit 6 to Rt. 132 in West Barnstable (Location 7)',
#      'Speed': 90.0,
#      'Status': 'Active',
#      'Title': 'Rt. 6 EB before Exit 6 to Rt. 132 in West Barnstable (Location 7) to Rt. 6 WB before Exit 2 to Rt. 130 in Sandwich (Location 6)',
#      'TravelTime': 477.0,
#      'dnid': '2044',
#      'onid': '2048',
#      'Route': {'type': 'LineString',
#       'coordinates': [[-70.3526103496563, 41.6845366092941],
#        [-70.3550028800973, 41.684546624899],
#        [-70.3567999601369, 41.6846247465639],
#        [-70.3581015020615, 41.6847644639208],
#        [-70.3597570955762, 41.6850163550199],
#        [-70.3607528656731, 41.6852261800533],
#        [-70.361759364606, 41.6854680538849],
#        [-70.3637609630836, 41.6861175532357],
#        [-70.364507287742, 41.6864064957124],
#        [-70.3655171394362, 41.6868481695728],
#        [-70.3729790449151, 41.690241245406],
#        [-70.373877584935, 41.6907054258963],
#        [-70.3754520416268, 41.6916182543504],
#        [-70.3779357671745, 41.6930593252357],
#        [-70.3828066587455, 41.6959013148191],
#        [-70.3852394223219, 41.6971390131001],
#        [-70.3891326487071, 41.6990956493309],
#        [-70.3910926729447, 41.700069939848],
#        [-70.3930634260184, 41.7010442156042],
#        [-70.3948812931783, 41.701854265092],
#        [-70.3966240584858, 41.702680324827],
#        [-70.3983400017031, 41.7035544346631],
#        [-70.4000827670105, 41.7044245276128],
#        [-70.4035119712361, 41.706140648813],
#        [-70.4069411754617, 41.7078727433655],
#        [-70.4078866541395, 41.7083608251658],
#        [-70.4088106751451, 41.7088969599802],
#        [-70.4096113145361, 41.7094050574752],
#        [-70.4103422164926, 41.7099251649388],
#        [-70.4130887985239, 41.7120405923542],
#        [-70.4144835472117, 41.7131323178863],
#        [-70.4158997535716, 41.7142240248762],
#        [-70.4167714715014, 41.7148251816066],
#        [-70.4175788164149, 41.7153382376497],
#        [-70.4193812608729, 41.7163563289293],
#        [-70.4204675555239, 41.7169732323421],
#        [-70.421575307847, 41.7175901298334],
#        [-70.4244023561488, 41.7192443368793],
#        [-70.4269692301761, 41.720692296177],
#        [-70.4295146465313, 41.7221522345483],
#        [-70.4322612285625, 41.7237087315538],
#        [-70.4350078105936, 41.7252812056746],
#        [-70.4362630844125, 41.7259813496559],
#        [-70.4369711875925, 41.7263274151465],
#        [-70.4376363754281, 41.7266334425846],
#        [-70.4384075105199, 41.7269624892668],
#        [-70.4392001032838, 41.7272675127849],
#        [-70.4400248825559, 41.7275485134809],
#        [-70.440860390664, 41.7278215058563],
#        [-70.4422373697172, 41.7281850768522],
#        [-70.4427882283936, 41.7283084352979],
#        [-70.4437575116763, 41.7285078601139],
#        [-70.4447589814673, 41.7286832633613],
#        [-70.4483464360248, 41.7291686849729],
#        [-70.452754646541, 41.7297621954852],
#        [-70.4543525725617, 41.73009097593],
#        [-70.4559504985823, 41.730515835839],
#        [-70.4577167332185, 41.7311003263869],
#        [-70.45921675861, 41.7316888149217],
#        [-70.4606953263295, 41.7323053209376],
#        [-70.4630462825309, 41.733268099341],
#        [-70.4653865098963, 41.7342308633135],
#        [-70.4683248698721, 41.7354317960659],
#        [-70.4696646332748, 41.7359601993631],
#        [-70.4714100807913, 41.7365106148418],
#        [-70.4724045097835, 41.7367808170778],
#        [-70.4736483842141, 41.7370730345128],
#        [-70.4748922586447, 41.7373412329063]]}}},
#    {'_index': 'mass_traffic',
#     '_type': 'record',
#     '_id': 'massdot1-7fa6c0570000',
#     '_score': 0.074107975,
#     '_source': {'LastUpdated': '2020-11-18T19:33:40',
#      'PairID': 'massdot1-7fa6c0570000',
#      'Destination': 'Route 24 SB at entrance in Randolph',
#      'Origin': 'Route 24 before Exit 21B to I-93 in Randolph',
#      'Speed': 94.0,
#      'Status': 'Active',
#      'Title': 'Route 24 before Exit 21B to I-93 in Randolph to Route 24 SB at entrance in Randolph',
#      'TravelTime': 50.0,
#      'dnid': '3097',
#      'onid': '3022',
#      'Route': {'type': 'LineString',
#       'coordinates': [[-71.0766994953165, 42.1877281751403],
#        [-71.0768818855295, 42.188849046742],
#        [-71.0771232843408, 42.190299790759],
#        [-71.0772493481647, 42.1910648957682],
#        [-71.0773646831524, 42.1918339660154],
#        [-71.0774773359308, 42.1931693835933],
#        [-71.077530980111, 42.1944093889367],
#        [-71.0775524377832, 42.1951883542105],
#        [-71.0775873065003, 42.1961401890491],
#        [-71.0776114463815, 42.1971079062236],
#        [-71.077648997308, 42.1982286114971],
#        [-71.0776704549802, 42.198351808382],
#        [-71.0776811838164, 42.1993254527322]]}}},
#    {'_index': 'mass_traffic',
#     '_type': 'record',
#     '_id': 'massdot1-5a07da570000',
#     '_score': 0.074107975,
#     '_source': {'LastUpdated': '2020-11-18T19:33:40',
#      'PairID': 'massdot1-5a07da570000',
#      'Destination': '3258 - R-93 - 3NB-TTR-31.7',
#      'FreeFlow': 60.0,
#      'Origin': '3080 - R-78 - 3NB-TTR-36.1',
#      'Speed': 106.0,
#      'Status': 'Active',
#      'Title': '3080 - R-78 - 3NB-TTR-36.1 to 3258 - R-93 - 3NB-TTR-31.7',
#      'TravelTime': 241.0,
#      'dnid': '3258',
#      'onid': '3080',
#      'Route': {'type': 'LineString',
#       'coordinates': [[-70.9174996614471, 42.1797410585229],
#        [-70.9161987900749, 42.1786955566604],
#        [-70.9153485298173, 42.1780237231469],
#        [-70.9144258499164, 42.1772584603014],
#        [-70.9135246276875, 42.1765249918958],
#        [-70.9126716852209, 42.1758352455526],
#        [-70.9118509292626, 42.175181271611],
#        [-70.9113413095498, 42.1747847096508],
#        [-70.9104239940666, 42.1740223893243],
#        [-70.9095656871818, 42.1733196947833],
#        [-70.9091043472313, 42.1729748050731],
#        [-70.9086483716985, 42.1726130167277],
#        [-70.908129364254, 42.1722462566498],
#        [-70.9077820181865, 42.1719749124592],
#        [-70.9073273837583, 42.1717095307513],
#        [-70.9069263935105, 42.1714759541694],
#        [-70.9056496620193, 42.1707235335285],
#        [-70.9050917625443, 42.1704243518965],
#        [-70.904319286348, 42.1700297480449],
#        [-70.903434157373, 42.1696097953981],
#        [-70.9025704860702, 42.1692335750972],
#        [-70.9016183018701, 42.1688528796219],
#        [-70.9006768465061, 42.1685039895894],
#        [-70.8995208144209, 42.1680755778292],
#        [-70.8982682228111, 42.1675914988688],
#        [-70.8969539403937, 42.1671203383768],
#        [-70.8960151672385, 42.166768456733],
#        [-70.8948832750342, 42.1663410272448],
#        [-70.8937567472479, 42.1659175709972],
#        [-70.8920535445233, 42.1652873515216],
#        [-70.8903503417987, 42.1646611019754],
#        [-70.8884245157261, 42.1639513449953],
#        [-70.8874776959438, 42.1636004397935],
#        [-70.8862894773502, 42.1631541014697],
#        [-70.8852782845514, 42.1627723753276],
#        [-70.8838070929066, 42.1622276163236],
#        [-70.8822983503356, 42.1616669470495],
#        [-70.879420340063, 42.1605933111698],
#        [-70.8780349791071, 42.160084321869],
#        [-70.8767515420937, 42.1596230467786],
#        [-70.8746513724347, 42.1589510106717],
#        [-70.8734028041381, 42.1586229431159],
#        [-70.8721542358415, 42.1583266867101],
#        [-70.8710625767725, 42.1580841133183],
#        [-70.8697241544741, 42.1578335857244],
#        [-70.8684661984461, 42.157642706892],
#        [-70.8672457933444, 42.1574478508233],
#        [-70.8652596175687, 42.1571406530475],
#        [-70.865151658656, 42.1571381676226],
#        [-70.864303410055, 42.1569925215483],
#        [-70.8627678453939, 42.1567211119286],
#        [-70.8612537384049, 42.1564178873505],
#        [-70.8599314093606, 42.1561136671333],
#        [-70.8588880300538, 42.1558412595541],
#        [-70.8586037158984, 42.1557497939726],
#        [-70.857418179514, 42.1554236982149],
#        [-70.8559322357199, 42.1549703427843],
#        [-70.855332762005, 42.1547893973854],
#        [-70.8547869324705, 42.1546004977908],
#        [-70.853802561762, 42.1542465580849],
#        [-70.8526840806027, 42.1538409168868],
#        [-70.8515924215336, 42.1534034577791],
#        [-70.849122107031, 42.1523654745252],
#        [-70.8480586111567, 42.1519101086837],
#        [-70.8468556404136, 42.1513791758148],
#        [-70.8448708057426, 42.150502231998],
#        [-70.8433473110222, 42.1498042476238]]}}}]}}
